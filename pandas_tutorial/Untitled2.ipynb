# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('countryName.csv')

# %%
df
# Out:
#            City        Country
# 0     MARIEHAMN  Åland Islands  \
# 1        Durrës        Albania
# 2        TIRANA        Albania
# 3        Annaba        Algeria
# 4         Batna        Algeria
# ...         ...            ...
# 4498      Gweru       Zimbabwe
# 4499     HARARE       Zimbabwe
# 4500     Mutare       Zimbabwe
# 4501        NaN  footnoteSeqID
# 4502      based             13
#
#                                        populationCounts
# 0     [{'year': '2013', 'value': '11370', 'sex': 'Bo...
# 1     [{'year': '2011', 'value': '113249', 'sex': 'B...
# 2     [{'year': '2011', 'value': '418495', 'sex': 'B...
# 3     [{'year': '1998', 'value': '352523', 'sex': 'B...
# 4     [{'year': '1998', 'value': '246800', 'sex': 'B...
# ...                                                 ...
# 4498  [{'year': '2012', 'value': '91806', 'sex': 'Bo...
# 4499  [{'year': '2012', 'value': '1485231', 'sex': '...
# 4500  [{'year': '2012', 'value': '262124', 'sex': 'B...
# 4501  [{'year': 'Footnote', 'value': None, 'sex': No...
# 4502  [{'year': 'Locations are generally based on St...
#
# [4503 rows x 3 columns]

# %%
df["populationCounts"].apply(pd.Series)
df = pd.concat([df, df["populationCounts"].apply(pd.Series)], axis=1)

# %%
df
# Out:
#            City        Country
# 0     MARIEHAMN  Åland Islands  \
# 1        Durrës        Albania
# 2        TIRANA        Albania
# 3        Annaba        Algeria
# 4         Batna        Algeria
# ...         ...            ...
# 4498      Gweru       Zimbabwe
# 4499     HARARE       Zimbabwe
# 4500     Mutare       Zimbabwe
# 4501        NaN  footnoteSeqID
# 4502      based             13
#
#                                        populationCounts
# 0     [{'year': '2013', 'value': '11370', 'sex': 'Bo...  \
# 1     [{'year': '2011', 'value': '113249', 'sex': 'B...
# 2     [{'year': '2011', 'value': '418495', 'sex': 'B...
# 3     [{'year': '1998', 'value': '352523', 'sex': 'B...
# 4     [{'year': '1998', 'value': '246800', 'sex': 'B...
# ...                                                 ...
# 4498  [{'year': '2012', 'value': '91806', 'sex': 'Bo...
# 4499  [{'year': '2012', 'value': '1485231', 'sex': '...
# 4500  [{'year': '2012', 'value': '262124', 'sex': 'B...
# 4501  [{'year': 'Footnote', 'value': None, 'sex': No...
# 4502  [{'year': 'Locations are generally based on St...
#
#                                                       0
# 0     [{'year': '2013', 'value': '11370', 'sex': 'Bo...
# 1     [{'year': '2011', 'value': '113249', 'sex': 'B...
# 2     [{'year': '2011', 'value': '418495', 'sex': 'B...
# 3     [{'year': '1998', 'value': '352523', 'sex': 'B...
# 4     [{'year': '1998', 'value': '246800', 'sex': 'B...
# ...                                                 ...
# 4498  [{'year': '2012', 'value': '91806', 'sex': 'Bo...
# 4499  [{'year': '2012', 'value': '1485231', 'sex': '...
# 4500  [{'year': '2012', 'value': '262124', 'sex': 'B...
# 4501  [{'year': 'Footnote', 'value': None, 'sex': No...
# 4502  [{'year': 'Locations are generally based on St...
#
# [4503 rows x 4 columns]

# %%
df.query('index==1')
# Out:
#      City  Country                                   populationCounts
# 1  Durrës  Albania  [{'year': '2011', 'value': '113249', 'sex': 'B...  \
#
#                                                    0
# 1  [{'year': '2011', 'value': '113249', 'sex': 'B...
